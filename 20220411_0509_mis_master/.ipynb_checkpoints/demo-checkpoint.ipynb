# %%
# %matplotlib inline

import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('Carseats.csv')

# %%
df.head()
# Out:
#    ID  Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  \
# 0   1  10.48        138      72            0         148     94    Medium
# 1   2  10.43         77      69            0          25     24    Medium
# 2   3   5.32        118      74            6         426    102    Medium
# 3   4   7.67        129     117            8         400    101       Bad
# 4   5   5.32        152     116            0         170    160    Medium
#
#    Age  Education Urban   US
# 0   27         17   Yes  Yes
# 1   50         18   Yes   No
# 2   80         18   Yes  Yes
# 3   36         10   Yes  Yes
# 4   39         16   Yes   No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320 entries, 0 to 319
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           320 non-null    int64
#  1   Sales        320 non-null    float64
#  2   CompPrice    320 non-null    int64
#  3   Income       320 non-null    int64
#  4   Advertising  320 non-null    int64
#  5   Population   320 non-null    int64
#  6   Price        320 non-null    int64
#  7   ShelveLoc    320 non-null    object
#  8   Age          320 non-null    int64
#  9   Education    320 non-null    int64
#  10  Urban        320 non-null    object
#  11  US           320 non-null    object
# dtypes: float64(1), int64(8), object(3)
# memory usage: 30.1+ KB

# %%
df.describe(include='all')
# Out:
#                 ID       Sales   CompPrice      Income  Advertising  \
# count   320.000000  320.000000  320.000000  320.000000   320.000000
# unique         NaN         NaN         NaN         NaN          NaN
# top            NaN         NaN         NaN         NaN          NaN
# freq           NaN         NaN         NaN         NaN          NaN
# mean    160.500000    7.560281  125.081250   68.168750     6.687500
# std      92.520268    2.824922   15.658372   28.001841     6.679109
# min       1.000000    0.000000   77.000000   21.000000     0.000000
# 25%      80.750000    5.545000  115.000000   42.000000     0.000000
# 50%     160.500000    7.525000  125.000000   69.000000     5.000000
# 75%     240.250000    9.322500  135.000000   90.000000    12.000000
# max     320.000000   16.270000  175.000000  120.000000    29.000000
#
#         Population       Price ShelveLoc         Age   Education Urban   US
# ...

# %%
sns.relplot('Population','Sales',height=6,aspect=12/6,data=df)
# Out:
# C:\ProgramData\Miniconda3\envs\dl\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot('Population','Sales',hue='ShelveLoc',height=6,aspect=12/6,data=df)
# Out:
# C:\ProgramData\Miniconda3\envs\dl\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot('Population','Sales',hue='ShelveLoc',size='Advertising',sizes=(30,200),height=6,aspect=12/6,data=df)
# Out:
# C:\ProgramData\Miniconda3\envs\dl\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
